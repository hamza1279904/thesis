# %%
# !pip install tensorflow pandas scikit-learn matplotlib keras-tuner
# Out:
# Requirement already satisfied: tensorflow in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (2.20.0)
# Requirement already satisfied: pandas in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: scikit-learn in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (1.7.1)
# Requirement already satisfied: matplotlib in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (3.10.5)
# Requirement already satisfied: keras-tuner in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (1.4.7)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (6.32.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (3.11.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (2.3.2)
# Requirement already satisfied: h5py>=3.11.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: kt-legacy in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import keras_tuner as kt
import random

print("Cell: Libraries imported.")

seed_value = 42 # You can use any integer
tf.random.set_seed(seed_value)
np.random.seed(seed_value)
random.seed(seed_value)
# Out:
# Cell: Libraries imported.

# %%
# --- This cell is configured for FinBERT ---
filename = 'BTC_with_FinBERT_sentiment.csv'
sentiment_column_name = 'sentiment_score' # Column name from the FinBERT script
# ----------------------------------------

# Load the data
try:
    df = pd.read_csv(filename)
except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")
    exit()

# Prepare the dataset
features = ['close_price', sentiment_column_name]
df = df.dropna(subset=features)
dataset = df[features].values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_dataset = scaler.fit_transform(dataset)

print("Cell : FinBERT dataset loaded and scaled.")
# Out:
# Cell : FinBERT dataset loaded and scaled.

# %%
def create_sequences(dataset, look_back=60):
    X, y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), :])
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# Split into training (80%) and testing (20%) sets
train_size = int(len(scaled_dataset) * 0.8)
train_data, test_data = scaled_dataset[0:train_size, :], scaled_dataset[train_size:len(scaled_dataset), :]

# Define the lookback period
look_back = 60

# Create the sequences for training and testing
X_train, y_train = create_sequences(train_data, look_back)
X_test, y_test = create_sequences(test_data, look_back)

print(f"Cell 4/11: Training and testing sequences created.")
# Out:
# Cell 4/11: Training and testing sequences created.

# %%
def build_model(hp):
    """
    This function builds the LSTM model and defines the hyperparameter search space.
    """
    model = Sequential()

    # Define Hyperparameter Search Space
    hp_units = hp.Int('units', min_value=32, max_value=128, step=16)
    hp_dropout = hp.Float('dropout', min_value=0.1, max_value=0.5, step=0.1)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    # Build the model using the hyperparameters
    model.add(LSTM(units=hp_units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(rate=hp_dropout))
    model.add(LSTM(units=hp_units, return_sequences=False))
    model.add(Dropout(rate=hp_dropout))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
        loss='mean_squared_error'
    )
    
    return model

print("Cell : Hyperparameter model builder function created.")
# Out:
# Cell : Hyperparameter model builder function created.

# %%
# Instantiate the tuner
tuner = kt.Hyperband(
    build_model,
    objective='val_loss', # The metric to minimize
    max_epochs=50,
    factor=3,
    directory='lstm_tuner',
    project_name='btc_sentiment_finbert' # New project name to avoid conflicts
)

# Create a callback to stop training early if the validation loss stops improving
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

print("Starting hyperparameter search... (This will take a significant amount of time)")
tuner.search(
    X_train,
    y_train,
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=[stop_early]
)

print("\nCell : Hyperparameter search complete.")
# Out:
# Reloading Tuner from lstm_tuner/btc_sentiment_finbert/tuner0.json
# Starting hyperparameter search... (This will take a significant amount of time)
#
# Cell : Hyperparameter search complete.

# %%
# Get the optimal hyperparameters from the tuner
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. 
The optimal number of units in the LSTM layers is {best_hps.get('units')}.
The optimal dropout rate is {best_hps.get('dropout')}.
The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.
""")

print("\nCell : Best hyperparameters retrieved.")
# Out:
# The hyperparameter search is complete.
# The optimal number of units in the LSTM layers is 96.
# The optimal dropout rate is 0.2.
# The optimal learning rate for the optimizer is 0.01.
#
#
# Cell : Best hyperparameters retrieved.

# %%
# Build the model with the optimal hyperparameters
final_model = tuner.hypermodel.build(best_hps)

print("Retraining the best model on the full training data... (This will take some time)")

# Retrain the model
history = final_model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]
)

print("\nCell : Final model training complete.")
# Out:
# Retraining the best model on the full training data... (This will take some time)
# Epoch 1/50
# /Users/hamza/Desktop/Thesis/thesis_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0407 - val_loss: 0.0016
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0021 - val_loss: 5.1625e-04
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0017 - val_loss: 4.1562e-04
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0018 - val_loss: 3.9043e-04
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0013 - val_loss: 8.2040e-04
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0015 - val_loss: 5.7829e-04
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0013 - val_loss: 3.9188e-04
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0014 - val_loss: 9.4916e-04
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 8.6198e-04
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 2.9340e-04
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - val_loss: 2.6419e-04
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011 - val_loss: 5.0297e-04
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - val_loss: 6.2192e-04
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 2.7074e-04
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011 - val_loss: 2.8996e-04
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 3.3789e-04
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - val_loss: 2.7786e-04
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - val_loss: 2.7140e-04
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.1967e-04 - val_loss: 2.7262e-04
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.7918e-04 - val_loss: 2.1460e-04
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0010 - val_loss: 4.3109e-04
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.6724e-04 - val_loss: 2.2732e-04
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.3260e-04 - val_loss: 3.8688e-04
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.8428e-04 - val_loss: 4.6471e-04
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.8849e-04 - val_loss: 7.7955e-04
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 2.5659e-04
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.5417e-04 - val_loss: 2.0824e-04
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.7031e-04 - val_loss: 2.1957e-04
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.8561e-04 - val_loss: 2.0785e-04
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.3962e-04 - val_loss: 2.7800e-04
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.1817e-04 - val_loss: 2.3333e-04
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.3171e-04 - val_loss: 4.1356e-04
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011 - val_loss: 4.6491e-04
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 7.7667e-04 - val_loss: 2.4355e-04
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.9358e-04 - val_loss: 3.0710e-04
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.2211e-04 - val_loss: 4.7305e-04
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.0354e-04 - val_loss: 2.0451e-04
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.0745e-04 - val_loss: 2.3390e-04
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.8555e-04 - val_loss: 5.2015e-04
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.4429e-04 - val_loss: 2.8336e-04
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.8169e-04 - val_loss: 3.2569e-04
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.1112e-04 - val_loss: 3.0261e-04
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.1364e-04 - val_loss: 2.4871e-04
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.6022e-04 - val_loss: 2.6377e-04
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.7493e-04 - val_loss: 2.3995e-04
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.1912e-04 - val_loss: 2.7763e-04
#
# Cell : Final model training complete.

# %%
# Make predictions on the test set using the final, retrained model
predictions_scaled = final_model.predict(X_test)

# Inverse the scaling to get actual price values
dummy_array = np.zeros((len(predictions_scaled), X_train.shape[2]))
dummy_array[:, 0] = predictions_scaled.flatten()
predictions = scaler.inverse_transform(dummy_array)[:, 0]

# Inverse scale the true values for comparison
dummy_array_y_test = np.zeros((len(y_test), X_train.shape[2]))
dummy_array_y_test[:, 0] = y_test.flatten()
y_test_actual = scaler.inverse_transform(dummy_array_y_test)[:, 0]

print("Cell : Predictions made with the final optimal model.")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Cell : Predictions made with the final optimal model.

# %%
# --- Quantitative Metrics ---
rmse = np.sqrt(mean_squared_error(y_test_actual, predictions))
mae = mean_absolute_error(y_test_actual, predictions)

# --- Directional Accuracy ---
results_df = pd.DataFrame({'true_price': y_test_actual, 'predicted_price': predictions})
results_df['true_direction'] = np.sign(results_df['true_price'].diff())
results_df['predicted_direction'] = np.sign(results_df['predicted_price'].diff())
correct_predictions = (results_df['true_direction'] * results_df['predicted_direction'] >= 0).sum()
directional_accuracy = correct_predictions / len(results_df.dropna())

print("\n--- Final Optimized Model Evaluation (FinBERT) ---")
print(f"Root Mean Squared Error (RMSE): ${rmse:.2f}")
print(f"Mean Absolute Error (MAE): ${mae:.2f}")
print(f"Directional Accuracy: {directional_accuracy:.2%}")
print("\nCell 10/11: Performance metrics calculated.")
# Out:
# --- Final Optimized Model Evaluation (FinBERT) ---
# Root Mean Squared Error (RMSE): $1072.79
# Mean Absolute Error (MAE): $760.69
# Directional Accuracy: 50.16%
#
# Cell 10/11: Performance metrics calculated.

# %%
# Make sure the 'date' column is in datetime format
df['date'] = pd.to_datetime(df['date'])

# Find the start date of the test set for plotting
plot_dates = df['date'].iloc[len(df) - len(predictions):]

plt.figure(figsize=(18, 9))
plt.plot(plot_dates, y_test_actual, color='black', label='Actual BTC Price')
plt.plot(plot_dates, predictions, color='blue', linestyle='--', alpha=0.8, label='Predicted BTC Price (Optimized with FinBERT)')
plt.title('Final Optimized LSTM Prediction vs. Actual Price (using FinBERT Sentiment)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.legend()
plt.grid(True)
plt.savefig('lstm_tuned_prediction_finbert.png')
plt.show()

print("\nCell : Visualization generated. Analysis finished.")
# Out:
# Cell : Visualization generated. Analysis finished.

# %%
# --- This is the new, upgraded evaluation cell ---

# --- Quantitative Metrics (RMSE & MAE) ---
rmse = np.sqrt(mean_squared_error(y_test_actual, predictions))
mae = mean_absolute_error(y_test_actual, predictions)

# --- Create a DataFrame for Directional Accuracy Analysis ---
# We need to align the true prices with the predictions.
# The first prediction corresponds to the price at index `train_size + look_back`.
results_df = pd.DataFrame({
    'true_price': y_test_actual.flatten(),
    'predicted_price': predictions.flatten()
}, index=df.index[train_size + look_back : train_size + look_back + len(y_test_actual)])


# --- 1. Short-Term (1-Day) Directional Accuracy ---
# This is the original method.
# It checks if the model correctly predicted if the next day's price would be up or down compared to the day before.
results_df['true_direction_1d'] = np.sign(results_df['true_price'].diff())
results_df['predicted_direction_1d'] = np.sign(results_df['predicted_price'].diff())
correct_predictions_1d = (results_df['true_direction_1d'] * results_df['predicted_direction_1d'] >= 0).sum()
directional_accuracy_1d = correct_predictions_1d / len(results_df.dropna())


# --- 2. Long-Term (7-Day) Directional Accuracy ---
# Here, we check if the model's prediction for TOMORROW can predict the trend for the NEXT 7 DAYS.
# The predicted direction is simply whether the model thinks tomorrow's price is higher than today's.
results_df['predicted_direction_longterm'] = np.sign(results_df['predicted_price'] - results_df['true_price'].shift(1))

# The actual long-term direction is whether the price in 7 days is higher than today's price.
results_df['true_direction_7d'] = np.sign(results_df['true_price'].shift(-6) - results_df['true_price'])
correct_predictions_7d = (results_df['predicted_direction_longterm'] * results_df['true_direction_7d'] >= 0).sum()
directional_accuracy_7d = correct_predictions_7d / len(results_df.dropna())


# --- 3. Long-Term (30-Day) Directional Accuracy ---
# Same logic, but for a 30-day horizon.
results_df['true_direction_30d'] = np.sign(results_df['true_price'].shift(-29) - results_df['true_price'])
correct_predictions_30d = (results_df['predicted_direction_longterm'] * results_df['true_direction_30d'] >= 0).sum()
directional_accuracy_30d = correct_predictions_30d / len(results_df.dropna())


# --- Print All Results ---
print("\n--- Final Optimized Baseline Model Evaluation ---")
print(f"Root Mean Squared Error (RMSE): ${rmse:.2f}")
print(f"Mean Absolute Error (MAE): ${mae:.2f}")
print("---------------------------------------------")
print(f"Directional Accuracy (1-Day Horizon): {directional_accuracy_1d:.2%}")
print(f"Directional Accuracy (7-Day Horizon): {directional_accuracy_7d:.2%}")
print(f"Directional Accuracy (30-Day Horizon): {directional_accuracy_30d:.2%}")
print("\nCell : Performance metrics calculated.")
# Out:
# --- Final Optimized Baseline Model Evaluation ---
# Root Mean Squared Error (RMSE): $1072.79
# Mean Absolute Error (MAE): $760.69
# ---------------------------------------------
# Directional Accuracy (1-Day Horizon): 50.16%
# Directional Accuracy (7-Day Horizon): 52.51%
# Directional Accuracy (30-Day Horizon): 45.29%
#
# Cell : Performance metrics calculated.

# %%
# --- Advanced Analysis: Volatility Regime Performance (Corrected) ---
# This cell assumes you have already run the model and have the following variables in memory:
# - df: The original dataframe with the full history
# - y_test_actual: The true prices for the test set
# - predictions: The model's predicted prices for the test set

try:
    # 1. Create a results dataframe with the correct date index
    # Get the actual dates for the test set predictions
    test_dates = df['date'].iloc[len(df) - len(predictions):]
    results_df = pd.DataFrame({
        'true_price': y_test_actual.flatten(),
        'predicted_price': predictions.flatten()
    }, index=pd.to_datetime(test_dates))


    # 2. Calculate daily returns and rolling volatility on the original full dataframe
    df['date'] = pd.to_datetime(df['date'])
    df = df.set_index('date')
    df['daily_return'] = df['close_price'].pct_change()
    df['volatility'] = df['daily_return'].rolling(window=30).std()


    # 3. Join the volatility data with the results dataframe
    # The join now works correctly because both dataframes share a datetime index
    regime_df = results_df.join(df['volatility']).dropna()


    # 4. Define the volatility regimes using quantiles (dividing data into three equal parts)
    low_vol_threshold = regime_df['volatility'].quantile(0.33)
    high_vol_threshold = regime_df['volatility'].quantile(0.66)

    def assign_regime(volatility):
        if volatility <= low_vol_threshold:
            return 'Low Volatility'
        elif volatility <= high_vol_threshold:
            return 'Normal Volatility'
        else:
            return 'High Volatility'

    regime_df['regime'] = regime_df['volatility'].apply(assign_regime)


    # 5. Calculate performance metrics for each regime
    print("\n--- Performance by Market Regime ---")

    for regime, group_df in regime_df.groupby('regime'):
        # Ensure the group is not empty
        if len(group_df) < 2:
            print(f"\nSkipping {regime}: Not enough data points.")
            continue

        rmse = np.sqrt(mean_squared_error(group_df['true_price'], group_df['predicted_price']))
        
        # Calculate directional accuracy for the subset
        group_df['true_direction'] = np.sign(group_df['true_price'].diff())
        group_df['predicted_direction'] = np.sign(group_df['predicted_price'].diff())
        
        # Calculate correct predictions, handling potential NaNs from diff()
        correct_predictions = (group_df['true_direction'] * group_df['predicted_direction'] >= 0).sum()
        directional_accuracy = correct_predictions / len(group_df.dropna(subset=['true_direction', 'predicted_direction']))
        
        print(f"\nResults for {regime} ({len(group_df)} days):")
        print(f"  - RMSE: ${rmse:.2f}")
        print(f"  - Directional Accuracy: {directional_accuracy:.2%}")

except NameError:
    print("Error: Please make sure you have run the full LSTM training and prediction script first.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# --- Performance by Market Regime ---
#
# Results for High Volatility (104 days):
#   - RMSE: $1323.61
#   - Directional Accuracy: 43.69%
#
# Results for Low Volatility (101 days):
#   - RMSE: $736.74
#   - Directional Accuracy: 54.00%
#
# Results for Normal Volatility (101 days):
#   - RMSE: $1067.75
#   - Directional Accuracy: 57.00%

# %%
model_name = 'LSTM_finBert'

# %%
# ## 12. Save Final Predictions to a File
# This cell takes the final 'true_price' and 'predicted_price' and saves them
# to a CSV file. This allows for easy comparison with other models later.

# Create a dataframe from the results
# The index will be the date, which is important for alignment later
predictions_df = pd.DataFrame({
    'true_price': y_test_actual.flatten(),
    'predicted_price': predictions.flatten()
}, index=plot_dates)

# Define the output filename using the model_name from Cell 2
output_filename = f'predictions_{model_name}.csv'

# Save to CSV
predictions_df.to_csv(output_filename)

print(f"\nCell 12/12: Predictions saved successfully to '{output_filename}'")
# Out:
# Cell 12/12: Predictions saved successfully to 'predictions_LSTM_finBert.csv'

# %%
# --- ADD THIS CELL TO PLOT TRAINING & VALIDATION LOSS ---

# Create a plot for the training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Training & Validation Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss (Mean Squared Error)')
plt.legend()
plt.grid(True)
plt.savefig('lstm_tuned_loss_curve_baseline.png')
plt.show()
